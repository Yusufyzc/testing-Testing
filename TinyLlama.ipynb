# %%
# Install transformers from source - only needed for versions <= v4.34
# pip install git+https://github.com/huggingface/transformers.git
# pip install accelerate

import torch
from transformers import pipeline

pipe = pipeline("text-generation", model="TinyLlama/TinyLlama-1.1B-Chat-v1.0", torch_dtype=torch.bfloat16, device_map="auto")

# We use the tokenizer's chat template to format each message - see https://huggingface.co/docs/transformers/main/en/chat_templating
messages = [
    {
        "role": "system",
        "content": "You are a friendly chatbot who always responds in the style of a pirate",
    },
    {"role": "user", "content": "Can you tell me story about stupid sailors in the sea?"},
]
prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
outputs = pipe(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
print(outputs[0]["generated_text"])
# <|system|>
# You are a friendly chatbot who always responds in the style of a pirate.</s>
# <|user|>
# How many helicopters can a human eat in one sitting?</s>
# <|assistant|>
# ...
# Out:
# Device set to use cuda:0
# <|system|>
# You are a friendly chatbot who always responds in the style of a pirate</s>
# <|user|>
# Can you tell me story about stupid sailors in the sea?</s>
# <|assistant|>
# Sure, here's a story about stupid sailors in the sea:
#
# Once upon a time, there were a group of seven pirates who were traveling the sea in a small wooden ship. They were in good spirits, having had a good day of looting and pillaging. As they sailed towards a nearby island, they spotted a group of friendly locals, who were fishing in the sea.
#
# The pirates were eager to show off their ship and invite the locals aboard. They convinced the locals to come aboard, and the pirates welcomed them with open arms. However, the locals were not impressed by the pirates' fancy manners and refusal to join the party.
#
# The locals asked the pirates if they were really a pirate crew, and the pirates admitted that they were. The locals were taken aback by the pirates' naivety, and they told them that they were actually fishermen. The pirates were taken aback by this, but they were not deterred.
#
# The pirates decided to teach the locals a lesson and asked them to join them in looting the
